# %% [markdown]
# # OOPS
#
#     OBJECT ORIENTED PROGRAMMING SYSTEM

# %% [markdown]
# Why we use opps
#
#      Object-oriented programming languages make it easier to understand how a program works by bringing together data and its behavior (or method) in single bundle called an “object.”

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = 'hari'
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# Here what is class stand for
#
#     just a classification  of any real world entity

# %%
class test:
    pass

# %%
a=test()

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class pwskills:
    def welcome():
        print('Welcome to pwskills')

# %%
rohan= pwskills()

# %%
rohan.welcome()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b76566df197c> in <module>
# ----> 1 rohan.welcome()
#
# TypeError: welcome() takes 0 positional arguments but 1 was given

# %%
class pwskills:
    def welcome(self): #whenever we try to declare a function inside a class then we supposed to give a pointer (or referer variable) in def
        print('Welcome to pwskills')

# %%
rohan= pwskills()

# %%
rohan.welcome()
# Out:
# Welcome to pwskills

# %%
hari=pwskills()
hari.welcome()
# Out:
# Welcome to pwskills

# %% [markdown]
# what if we want to pass a data with respect to class
#
#     this will be happend with a help of constructor
#     __int__

# %%
class pwskills1:
    
    #constructor part
    def __init__(self, phone_number,email_id, Student_id): # self is not a reserved keyword we can use anythere for our convention
        self.phone_number= phone_number
        self.email_id = email_id 
        self.student_id = Student_id 

    def return_student_detials(self):
        return self.phone_number, self.email_id, self.student_id

# %%
rohan =  pwskills1() # here it needs to give a datas of the student
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-0ac16d05bdd2> in <module>
# ----> 1 rohan =  pwskills1() # here it needs to give a datas of the student
#
# TypeError: __init__() missing 3 required positional arguments: 'phone_number', 'email_id', and 'Student_id'

# %%
rohan = pwskills1(1456782,'rohan@gmail.com',101)

# %%
rohan.return_student_detials()
# Out:
# (1456782, 'rohan@gmail.com', 101)

# %%
rohan.phone_number
# Out:
# 1456782

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %% [markdown]
# POLYMORPHISM

# %%
class data_science:
    def syllabus(self):
        print('this is my data science program syllabus'.upper())

# %%
class full_stock:
    def syllabus(self):
        print('this is my full stock program syllabus'.upper())

# %%
def program(lst):
    for i in lst:
        i.syllabus()

# %%
ds=data_science()
fs=full_stock()

# %%
pro=[ds,fs]

# %%
program(pro)
# Out:
# THIS IS MY DATA SCIENCE PROGRAM SYLLABUS
# THIS IS MY FULL STOCK PROGRAM SYLLABUS

# %%
pro1=(ds,fs)
program(pro1)
# Out:
# THIS IS MY DATA SCIENCE PROGRAM SYLLABUS
# THIS IS MY FULL STOCK PROGRAM SYLLABUS

# %%
pro2={ds,fs}
program(pro2)
# Out:
# THIS IS MY FULL STOCK PROGRAM SYLLABUS
# THIS IS MY DATA SCIENCE PROGRAM SYLLABUS

# %% [markdown]
# ENCAPSULATION

# %% [markdown]
#     It describes the idea of wrapping data and the methods that work on data within one unit. This puts restrictions on accessing variables and methods directly and can prevent the accidental modification of data.
#
#     To prevent accidental change, an object’s variable can only be changed by an object’s method. Those types of variables are known as private variables.

# %%
class test:
    def __init__(self, a, b):
        self.a=b
        self.b=a

# %%
t=test(45,56)

# %%
 t.a
# Out:
# 56

# %%
t.b
# Out:
# 45

# %%
class car:
    def __init__(self, year, make, model, speed):
        self.__year = year      # here why we start year with dould underscore becouse its actually make data as private
        self.__make = make
        self.__model = model
        self.__speed = 0

    def set_speed(self, speed):
        self.__speed = 0 if speed < 0 else speed

    def get_speed(self):
        return self.__speed

# %%
obj_car = car(2021,'tata', 'tiago', 12)

# %%
obj_car._car__year = 2023

# %%
obj_car._car__year
# Out:
# 2023

# %%
obj_car.set_speed(-123)

# %%
obj_car._car__speed
# Out:
# 0

# %%
obj_car.set_speed(123)

# %%
obj_car._car__speed
# Out:
# 123

# %%
obj_car.get_speed()
# Out:
# 123

# %%
class bank_account:

    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance = self.__balance + amount

    def withdraw(self, amount):
        if self.__balance >= amount :
            self.__balance = self.__balance - amount
            return True
        else:
            return False
        
    def get_balance(self):
        return self.__balance

# %%
obj_bank = bank_account(1000)

# %%
obj_bank.get_balance()
# Out:
# 1000

# %%
obj_bank.deposit(5000)

# %%
obj_bank.get_balance()
# Out:
# 6000

# %%
obj_bank.withdraw(2000)
# Out:
# True

# %%
obj_bank.get_balance()
# Out:
# 4000

# %%
obj_bank.withdraw(5000)
# Out:
# False

# %%
obj_bank.withdraw(500)
# Out:
# True

# %%
obj_bank.get_balance()
# Out:
# 3500

# %% [markdown]
# INHERITANCE

# %%
class parent:

    def test_parent(self):
        print('this is my parent class')

# %%
class child(parent):
    pass

# %%
child_obj = child()

# %%
child_obj.test_parent()
# Out:
# this is my parent class

# %% [markdown]
# Multi label inheritance

# %%
class class1:
    def test_class1(self):
        print('this is my class1 ')

# %%
class class2(class1):
    def test_class2(self):
        print('This is my class 2')

# %%
class class3(class2):
    def test_class3(self):
        print('This is my class 3 ')

# %%
obj_class3 = class3()

# %%
obj_class3.test_class2()
# Out:
# This is my class 2

# %%
obj_class3.test_class1()
# Out:
# this is my class1

# %%
obj_class3.test_class3()
# Out:
# This is my class 3

# %%
obj_class2 = class2()

# %%
obj_class2.test_class1()
# Out:
# this is my class1

# %%
obj_class2.test_class2()
# Out:
# This is my class 2

# %%
obj_class2.test_class3()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-00c40745d208> in <module>
# ----> 1 obj_class2.test_class3()
#
# AttributeError: 'class2' object has no attribute 'test_class3'

# %%
class class4:
    def test_class1(self):
        print('this is my class4 ')

# %%
class class5():
    def test_class2(self):
        print('This is my class 5 ')

# %%
class class6(class4,class5):
    def test_class3(self):
        print('This is my class 6 ')

# %%
obj_class6 = class6()

# %%
obj_class6.test_class1()
# Out:
# this is my class4

# %%
obj_class6.test_class2()
# Out:
# This is my class 5

# %% [markdown]
# ABSTRACT CLASS

# %% [markdown]
# DECORATOR

# %%
def test():
    print('this is the start of my function')
    print(4+5)
    print('this is the end of my function')

# %%
test()
# Out:
# this is the start of my function
# 9
# this is the end of my function

# %% [markdown]
# USING DECORATOR

# %%
def deco(function1):
    def inner_deco():
        print('This is the start of the my Function')
        function1()
        print('End of Function')
    return inner_deco()

# %%
@deco
def function1():
    print(5*8)
# Out:
# This is the start of the my Function
# 40
# End of Function

# %% [markdown]
# class methods
#
#     basically function overloading not possible in python but by the use of class method and decorator we do that

# %%
class pwskills:
    def __init__(self, name, email):
        self.name= name
        self.email = email

    def student_details(self):
        print(self.name , self.email)

# %%
pw = pwskills('hari','hari_@gmail.com')

# %%
pw.student_details()
# Out:
# hari hari_@gmail.com

# %%
class pwskills1:
    def __init__(self, name, email):
        self.name= name
        self.email = email

    @classmethod
    def details(cls, name1, email1):
        return cls(name1, email1)

    def student_details(self):
        print(self.name , self.email)

# %%
pw1 = pwskills1.details('krish','krishna@gmail.com')

# %%
pw1.name
# Out:
# 'krish'

# %%
pw1.email
# Out:
# 'krishna@gmail.com'

# %%
pw1.student_details()
# Out:
# krish krishna@gmail.com

# %%
class pwskills2:

    mobile_number = 912345678
    def __init__(self, name, email):
        self.name= name
        self.email = email

    @classmethod
    def details(cls, name1, email1):
        return cls(name1, email1)

    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
pwskills2.mobile_number
# Out:
# 912345678

# %%
pw2 = pwskills2('ram','ram@gmail.com')

# %%
pw2.student_details()
# Out:
# ram ram@gmail.com 912345678

# %% [markdown]
# STATIC METHOD

# %%
class pwskills:
    def student_details(self, name, mail_id, number):
        print(name, mail_id,number)

# %%
pw = pwskills()

# %%
pw.student_details('hari', 'hari@gmail.com', 123467)
# Out:
# hari hari@gmail.com 123467

# %%
class pwskills:
    def student_details(self, name, mail_id, number):
        print(name, mail_id,number)

    @staticmethod
    def mentor_class(list_mentor):
        print(list_mentor)
    def mentor(self, mentor_list):
        print(mentor_list)

# %%
pw1 = pwskills()
pw1.mentor(['hari','KRISH'])
# Out:
# ['hari', 'KRISH']

# %%
pw1.mentor_class(['hari1','krishna1'])
# Out:
# ['hari1', 'krishna1']

# %%
pwskills.mentor_class(['hari2','krishna2'])
# Out:
# ['hari2', 'krishna2']

# %% [markdown]
# Special (Magic Dunder) Methods
